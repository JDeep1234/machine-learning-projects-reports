# %%
from sklearn.cluster import KMeans
import pandas as p
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df=p.read_csv("C:\\Users\\User\\Desktop\\Book1.csv")

# %%
df.head()
# Out:
#        City   AirQuality   WaterPollution
# 0      Agra    23.611111        69.827586
# 1  Amritsar    21.568627        76.704545
# 2    Bhopal    48.928571        67.307692
# 3       Che    35.884354        73.070175
# 4     Delhi    11.844136        77.416799

# %%
df.columns
# Out:
# Index(['City', ' AirQuality', ' WaterPollution'], dtype='object')

# %%
plt.scatter(df['City'],df[' AirQuality'])
plt.title('Scatter Plot of Air Pollution')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Air Pollution')

# %%
aqi=df[' AirQuality']
city=df['City']
plt.bar(city,aqi)
plt.xlabel('STATES')
plt.ylabel('AQI')
plt.title('AIR QUALITY INDEX')
plt.show()

# %%
plt.scatter(df['City'],df[' WaterPollution'])
plt.title('Scater plot of water pollution')
# Out:
# Text(0.5, 1.0, 'Scater plot of water pollution')

# %%
wqi=df[' WaterPollution']
city=df['City']

plt.bar(city,wqi)
plt.xlabel('STATES')
plt.ylabel('waterpollution')
plt.title('water pollution')
plt.show()

# %%
sns.pairplot(df)

# %%
wqi.plot(kind = 'area')
# Out:
# <AxesSubplot:>

# %%
aqi.plot(kind = 'area')
# Out:
# <AxesSubplot:>
